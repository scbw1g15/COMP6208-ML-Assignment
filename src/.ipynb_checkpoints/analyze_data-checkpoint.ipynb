# %%
"""import data using pandas"""

import os
import pandas as pd
S1_PATH = os.path.join('..','Datasets_Healthy_Older_People','S1_Dataset')
S2_PATH = os.path.join('..','Datasets_Healthy_Older_People','S2_Dataset')

print("Importing Data...")
data_path = os.path.join(S1_PATH, "d1p01M")
s1_data = pd.read_csv(data_path, header=None)
print("Done")
# Out:
# Importing Data...
# Done

# %%
"""some quick information about the data"""
s1_data.info()
s1_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 9 columns):
# 0    401 non-null float64
# 1    401 non-null float64
# 2    401 non-null float64
# 3    401 non-null float64
# 4    401 non-null int64
# 5    401 non-null float64
# 6    401 non-null float64
# 7    401 non-null float64
# 8    401 non-null int64
# dtypes: float64(7), int64(2)
# memory usage: 28.3 KB
#       0        1        2         3  4     5       6       7  8
# 0  0.00  0.27203  1.00820 -0.082102  1 -63.5  2.4252  924.25  1
# 1  0.50  0.27203  1.00820 -0.082102  1 -63.0  4.7369  921.75  1
# 2  1.50  0.44791  0.91636 -0.013684  1 -63.5  3.0311  923.75  1
# 3  1.75  0.44791  0.91636 -0.013684  1 -63.0  2.0371  921.25  1
# 4  2.50  0.34238  0.96229 -0.059296  1 -63.5  5.8920  920.25  1

# %%
for x,c in [(1,'r'),(2,'g'),(3,'b'),(4,'y')]:
    s1_data.loc[s1_data[8] == x].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114 entries, 0 to 400
# Data columns (total 9 columns):
# 0    114 non-null float64
# 1    114 non-null float64
# 2    114 non-null float64
# 3    114 non-null float64
# 4    114 non-null int64
# 5    114 non-null float64
# 6    114 non-null float64
# 7    114 non-null float64
# 8    114 non-null int64
# dtypes: float64(7), int64(2)
# memory usage: 8.9 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 223 to 282
# Data columns (total 9 columns):
# 0    60 non-null float64
# 1    60 non-null float64
# 2    60 non-null float64
# 3    60 non-null float64
# 4    60 non-null int64
# 5    60 non-null float64
# 6    60 non-null float64
# 7    60 non-null float64
# 8    60 non-null int64
# dtypes: float64(7), int64(2)
# memory usage: 4.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 220 entries, 55 to 392
# Data columns (total 9 columns):
# 0    220 non-null float64
# 1    220 non-null float64
# 2    220 non-null float64
# 3    220 non-null float64
# 4    220 non-null int64
# 5    220 non-null float64
# 6    220 non-null float64
# 7    220 non-null float64
# 8    220 non-null int64
# dtypes: float64(7), int64(2)
# memory usage: 17.2 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 219 to 285
# Data columns (total 9 columns):
# 0    7 non-null float64
# 1    7 non-null float64
# 2    7 non-null float64
# 3    7 non-null float64
# 4    7 non-null int64
# 5    7 non-null float64
# 6    7 non-null float64
# 7    7 non-null float64
# 8    7 non-null int64
# dtypes: float64(7), int64(2)
# memory usage: 560.0 bytes

# %%
"""plot acc-x acc-y acc-z against type of activity"""
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
for x,c,action in [(1,'r', 'sit on bed'),(2,'g','sit on chair'),(3,'b', 'lying'),(4,'k', 'ambulating')]:
    xs = s1_data.loc[s1_data[8] == x][1]
    ys = s1_data.loc[s1_data[8] == x][2]
    zs = s1_data.loc[s1_data[8] == x][3]
    ax.scatter(xs, ys, zs, c=c, marker='.', label=action)

ax.legend()
ax.set_xlabel('frontal')
ax.set_ylabel('vertical')
ax.set_zlabel('lateral')
ax.view_init(None, 30)

plt.show()
